# %%
import pandas as pd

# %%
# Topic: Serices

# loc :end is include work with lable data
# iloc: end is not include work with index 
# lst[0:1] similar to iloc

# sr.get(idx, customize_value)
# idx = lable or normal iddx

# %%
# Datafram 
ser1 = pd.Series([10, 20, 30, 40,], index = [1,2,3,4])

ser2 = pd.Series(["A", "B", "c", "d",], index = [4,2,3,6])


df = pd.DataFrame({"Number ": ser1, "leter": ser2})

df
# Out:
#    Number  leter
# 1     10.0   NaN
# 2     20.0     B
# 3     30.0     c
# 4     40.0     A
# 6      NaN     d

# %%
my_dict = {
    "Name": ["Kz", "Ra", "KzRaihan"],
    "age" : [24,35, 30]
}


df = pd.DataFrame(my_dict,index = [1,2,3])
df
# Out:
#        Name  age
# 1        Kz   24
# 2        Ra   35
# 3  KzRaihan   30

# %%
df.loc[1]
# Out:
# Name    Kz
# age     24
# Name: 1, dtype: object

# %%
df.iloc[:]
# Out:
#        Name  age
# 1        Kz   24
# 2        Ra   35
# 3  KzRaihan   30

# %%
df.iloc[-1]
# Out:
# Name    KzRaihan
# age           30
# Name: 3, dtype: object

# %%
df.iloc[::-1]
# Out:
#        Name  age
# 3  KzRaihan   30
# 2        Ra   35
# 1        Kz   24

# %%
df.loc[:]
# Out:
#        Name  age
# 1        Kz   24
# 2        Ra   35
# 3  KzRaihan   30

# %%
df.loc[:1]
# Out:
#   Name  age
# 1   Kz   24

# %%
df.loc[[1,3]]
# Out:
#        Name  age
# 1        Kz   24
# 3  KzRaihan   30

# %%
df.drop("Name",axis = 1) # column delete
# Out:
#    age
# 1   24
# 2   35
# 3   30

# %%
df.drop("age", axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.drop("age", axis=0)
#
# File c:\Users\HP\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df
# Out:
#        Name  age
# 1        Kz   24
# 2        Ra   35
# 3  KzRaihan   30

# %%
df.drop(2, axis=0) # here row delete here 2 is row
# Out:
#        Name  age
# 1        Kz   24
# 3  KzRaihan   30

# %%
df["Name"] = "Raihan"
df
# Out:
#      Name  age
# 1  Raihan   24
# 2  Raihan   35
# 3  Raihan   30

# %%
df
# Out:
#      Name  age
# 1  Raihan   24
# 2  Raihan   35
# 3  Raihan   30

# %%
my_dict = {
    "Name": ["Kz", "Ra", "KzRaihan"],
    "age" : [24,35, 30]
}


df = pd.DataFrame(my_dict,index = [1,2,3])
df
# Out:
#        Name  age
# 1        Kz   24
# 2        Ra   35
# 3  KzRaihan   30

# %%
df.drop("Name", axis=1, inplace = True)
df
# Out:
#    age
# 1   24
# 2   35
# 3   30

# %%
my_dict = {
    "Name": ["Kz", "Ra", "KzRaihan"],
    "age" : [24,35, 30]
}


df = pd.DataFrame(my_dict,index = [1,2,3])
df
# Out:
#        Name  age
# 1        Kz   24
# 2        Ra   35
# 3  KzRaihan   30

# %%
df["age"] = df["age"] + 2

df # permanent change
# Out:
#        Name  age
# 1        Kz   26
# 2        Ra   37
# 3  KzRaihan   32

# %%
df
# Out:
#        Name  age
# 1        Kz   26
# 2        Ra   37
# 3  KzRaihan   32

# %%
df = pd.read_csv("student_data (1).csv")
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df.head(2)
# Out:
#   StudentID       FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001    Alif Rahman                  85.0             85.0
# 1    PH1002  Fatima Akhter                  92.0             92.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram

# %%
df.tail(3)
# Out:
#    StudentID      FullName  Data Structure Marks  Algorithm Marks  \
# 17    PH1018   Babul Ahmed                  88.0             88.0
# 18    PH1019  Faria Rahman                   NaN              NaN
# 19    PH1020    Nasir Khan                  86.0             86.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 17          85.0        Completed     2025-09-05  Ms. Salma      Sylhet
# 18           NaN      Not Started     2025-09-15  Mr. David  Chattogram
# 19          89.0        Completed     2025-10-02  Ms. Salma       Dhaka

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   StudentID             20 non-null     object
#  1   FullName              20 non-null     object
#  2   Data Structure Marks  16 non-null     float64
#  3   Algorithm Marks       16 non-null     float64
#  4   Python Marks          15 non-null     float64
#  5   CompletionStatus      20 non-null     object
#  6   EnrollmentDate        20 non-null     object
#  7   Instructor            20 non-null     object
#  8   Location              20 non-null     object
# dtypes: float64(3), object(6)
# memory usage: 1.5+ KB

# %%
df.describe()
# Out:
#        Data Structure Marks  Algorithm Marks  Python Marks
# count             16.000000        16.000000     15.000000
# mean              84.000000        84.000000     85.666667
# std                6.501282         6.501282      5.394000
# min               72.000000        72.000000     76.000000
# 25%               79.500000        79.500000     83.000000
# 50%               85.500000        85.500000     85.000000
# 75%               88.250000        88.250000     88.500000
# max               94.000000        94.000000     95.000000

# %%
df.dtypes
# Out:
# StudentID                object
# FullName                 object
# Data Structure Marks    float64
# Algorithm Marks         float64
# Python Marks            float64
# CompletionStatus         object
# EnrollmentDate           object
# Instructor               object
# Location                 object
# dtype: object

# %%
df.isnull() # Return boolean value 
# is null then reutn true else false
# Out:
#     StudentID  FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 0       False     False                 False            False         False
# 1       False     False                 False            False          True
# 2       False     False                 False            False         False
# 3       False     False                 False            False         False
# 4       False     False                  True             True         False
# 5       False     False                 False            False         False
# 6       False     False                 False            False          True
# 7       False     False                 False            False         False
# 8       False     False                 False            False         False
# 9       False     False                 False            False         False
# 10      False     False                  True             True         False
# ...

# %%
df.isnull().sum()
# summation of the null values of each columns
# Out:
# StudentID               0
# FullName                0
# Data Structure Marks    4
# Algorithm Marks         4
# Python Marks            5
# CompletionStatus        0
# EnrollmentDate          0
# Instructor              0
# Location                0
# dtype: int64

# %%
df = df.fillna(0)

# return a df

# %%
df.isnull().sum()
# Out:
# StudentID               0
# FullName                0
# Data Structure Marks    0
# Algorithm Marks         0
# Python Marks            0
# CompletionStatus        0
# EnrollmentDate          0
# Instructor              0
# Location                0
# dtype: int64

# %%
# spefic column k 

df["New_Python Mars"] = df["Python"].filna(df[])

# %%
df.head(2)
# Out:
#   StudentID       FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001    Alif Rahman                  85.0             85.0
# 1    PH1002  Fatima Akhter                  92.0             92.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           0.0      In Progress     2024-01-20  Ms. Salma  Chattogram

# %%
# rename

df = df.rename(columns ={"StudentID": "ID"})
df.head(1)
# Out:
#        ID     FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 0  PH1001  Alif Rahman                  85.0             85.0          88.0
#
#   CompletionStatus EnrollmentDate Instructor Location
# 0        Completed     2024-01-15  Mr. Karim    Dhaka

# %%
# column ar value change 
df["vale2x"] = df["Python Marks"].apply(lambda x:x*2)
df.head(2)
# Out:
#        ID       FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 0  PH1001    Alif Rahman                  85.0             85.0          88.0
# 1  PH1002  Fatima Akhter                  92.0             92.0           0.0
#
#   CompletionStatus EnrollmentDate Instructor    Location  vale2x
# 0        Completed     2024-01-15  Mr. Karim       Dhaka   176.0
# 1      In Progress     2024-01-20  Ms. Salma  Chattogram     0.0

# %%
df["vale3x"] = df["Python Marks"].map(lambda x:x*2)
df.head(2)
# Out:
#        ID       FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 0  PH1001    Alif Rahman                  85.0             85.0          88.0
# 1  PH1002  Fatima Akhter                  92.0             92.0           0.0
#
#   CompletionStatus EnrollmentDate Instructor    Location  vale2x  vale3x
# 0        Completed     2024-01-15  Mr. Karim       Dhaka   176.0   176.0
# 1      In Progress     2024-01-20  Ms. Salma  Chattogram     0.0     0.0

# %%
df.head(2)
# Out:
#        ID       FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 0  PH1001    Alif Rahman                  85.0             85.0          88.0
# 1  PH1002  Fatima Akhter                  92.0             92.0           0.0
#
#   CompletionStatus EnrollmentDate Instructor    Location  vale2x  vale3x
# 0        Completed     2024-01-15  Mr. Karim       Dhaka   176.0   176.0
# 1      In Progress     2024-01-20  Ms. Salma  Chattogram     0.0     0.0

# %%
# sorting

df = df.sort_values(["Python Marks"], ascending = False)

df.head(3)
# Out:
#         ID      FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 4   PH1005   Kamal Uddin                   0.0              0.0          95.0
# 16  PH1017   Afsana Mimi                  90.0             90.0          93.0
# 10  PH1011  Rahim Sheikh                   0.0              0.0          91.0
#
#    CompletionStatus EnrollmentDate Instructor    Location  vale2x  vale3x
# 4       In Progress     2024-03-05  Mr. Karim  Chattogram   190.0   190.0
# 16        Completed     2025-09-01  Mr. Karim       Dhaka   186.0   186.0
# 10      In Progress     2024-06-11  Mr. Karim      Khulna   182.0   182.0

# %%
# sorting

df = df.sort_values(["Python Marks"], ascending = True)

df.head(3)
# Out:
#         ID       FullName  Data Structure Marks  Algorithm Marks  \
# 1   PH1002  Fatima Akhter                  92.0             92.0
# 15  PH1016   Ziaur Rahman                  94.0             94.0
# 13  PH1014     Urmi Akter                   0.0              0.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location  \
# 1            0.0      In Progress     2024-01-20  Ms. Salma  Chattogram
# 15           0.0      In Progress     2024-08-21  Ms. Salma  Chattogram
# 13           0.0      Not Started     2024-07-09  Ms. Salma    Rajshahi
#
#     vale2x  vale3x
# 1      0.0     0.0
# 15     0.0     0.0
# 13     0.0     0.0

# %%
df[df(["Category"] == 90]
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 df (df["Category"] == 90)
#       2 df
#
# ...
