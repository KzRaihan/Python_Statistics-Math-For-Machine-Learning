# %% [markdown]
# ## Topic: Handling Null Values

# %% [markdown]
# ### OUTCOMES
#
# - 1. Drop The NaN Values Rows or Columns
#
#     - Drop All Rows
#         - df.dropna()
#
#     - Drop Rows with Specific Columns have NaN
#         - df.dropna(subset =["col], inplace = True)
#
# - 2. Fill NaN Values
#
#     - fill with constant value
#         - df.fillna(value)
#         - df['col_name'].fillna(value)
#
#
#     - fill with Statistical Measures
#         -  df['col_name'].fillna(df['col_name'].mean())

# %%
import pandas as pd

# %%
df = pd.read_csv("student_data.csv")

df.head(6)
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
# 5    PH1006       Laila Begum                  75.0             75.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
# 5          78.0        Completed     2024-03-08  Ms. Salma    Rajshahi

# %%
## how many unique values
# df.nunique()
len(df)
# Out:
# 20

# %% [markdown]
# ### 1. Drop The NaN Values Rows or Columns

# %% [markdown]
# #### Drop All Rows
#
# - syntax:
#     - df.dropna(how = 'any')
#
#     - how => how to drop rows
#     - any => if at least one NaN the drop rows (Default)
#
#     - all => if all rows contain NaN then only drop.

# %%
# df.dropna(how = 'any') [- if at least one NaN is Present]
new_df = df.dropna()

new_df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# 19    PH1020        Nasir Khan                  86.0             86.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0           88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 2           85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3           82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 5           78.0        Completed     2024-03-08  Ms. Salma    Rajshahi
# 7           85.0        Completed     2024-04-22  Ms. Salma  Chattogram
# 8           76.0        Completed     2024-05-16  Mr. David       Dhaka
# 9           88.0        Completed     2024-05-20  Ms. Salma      Sylhet
# 11          87.0        Completed     2024-06-14  Ms. Salma  Chattogram
# 12          79.0        Completed     2024-07-02  Mr. David       Dhaka
# 14          84.0        Completed     2024-08-18  Mr. Karim       Dhaka
# 16          93.0        Completed     2025-09-01  Mr. Karim       Dhaka
# 17          85.0        Completed     2025-09-05  Ms. Salma      Sylhet
# 19          89.0        Completed     2025-10-02  Ms. Salma       Dhaka

# %%
# after drop the entire NaN then total unique rows
len(new_df)
# Out:
# 13

# %%
# df.dropna(how = "all") [- if entire rows is NaN then only drop]

new_d = df.dropna(how = "all")

print(new_d)

print("Total rows : ", len(new_d))
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 13    PH1014        Urmi Akter                   NaN              NaN
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 15    PH1016      Ziaur Rahman                  94.0             94.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# 18    PH1019      Faria Rahman                   NaN              NaN
# 19    PH1020        Nasir Khan                  86.0             86.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0           88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1            NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2           85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3           82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4           95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
# 5           78.0        Completed     2024-03-08  Ms. Salma    Rajshahi
# 6            NaN      In Progress     2024-04-01  Mr. Karim       Dhaka
# 7           85.0        Completed     2024-04-22  Ms. Salma  Chattogram
# 8           76.0        Completed     2024-05-16  Mr. David       Dhaka
# 9           88.0        Completed     2024-05-20  Ms. Salma      Sylhet
# 10          91.0      In Progress     2024-06-11  Mr. Karim      Khulna
# 11          87.0        Completed     2024-06-14  Ms. Salma  Chattogram
# 12          79.0        Completed     2024-07-02  Mr. David       Dhaka
# 13           NaN      Not Started     2024-07-09  Ms. Salma    Rajshahi
# 14          84.0        Completed     2024-08-18  Mr. Karim       Dhaka
# 15           NaN      In Progress     2024-08-21  Ms. Salma  Chattogram
# 16          93.0        Completed     2025-09-01  Mr. Karim       Dhaka
# 17          85.0        Completed     2025-09-05  Ms. Salma      Sylhet
# 18           NaN      Not Started     2025-09-15  Mr. David  Chattogram
# 19          89.0        Completed     2025-10-02  Ms. Salma       Dhaka
# Total rows :  20

# %% [markdown]
# #### Drop Rows with Specific Columns have NaN
#
# - Syntax :
#     - df.dropna(subset =["col1', 'col2'], inplace = True)

# %%
# drop with specific column wise

df.dropna(subset=['Python Marks', 'Algorithm Marks'])

# if  Python Marks and Algorithm Marks has NaN then drop entire rows
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# 19    PH1020        Nasir Khan                  86.0             86.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0           88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 2           85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3           82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 5           78.0        Completed     2024-03-08  Ms. Salma    Rajshahi
# 7           85.0        Completed     2024-04-22  Ms. Salma  Chattogram
# 8           76.0        Completed     2024-05-16  Mr. David       Dhaka
# 9           88.0        Completed     2024-05-20  Ms. Salma      Sylhet
# 11          87.0        Completed     2024-06-14  Ms. Salma  Chattogram
# 12          79.0        Completed     2024-07-02  Mr. David       Dhaka
# 14          84.0        Completed     2024-08-18  Mr. Karim       Dhaka
# 16          93.0        Completed     2025-09-01  Mr. Karim       Dhaka
# 17          85.0        Completed     2025-09-05  Ms. Salma      Sylhet
# 19          89.0        Completed     2025-10-02  Ms. Salma       Dhaka

# %% [markdown]
# #### Drop Column with all Null Values

# %%
df1 = df.dropna(axis = 1, how = "all")

df1.head(2)

# axis = 1 means column
# Out:
#   StudentID       FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001    Alif Rahman                  85.0             85.0
# 1    PH1002  Fatima Akhter                  92.0             92.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram

# %%
# Drop column with at least one value is NaN

df2 = df.dropna(axis = 1, how = 'any')

df2

# here -> Delete all column which contain at least one NaN value
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate Instructor  \
# 0     PH1001       Alif Rahman        Completed     2024-01-15  Mr. Karim
# 1     PH1002     Fatima Akhter      In Progress     2024-01-20  Ms. Salma
# 2     PH1003     Imran Hossain        Completed     2024-02-10  Mr. Karim
# 3     PH1004  Jannatul Ferdous        Completed     2024-02-12  Ms. Salma
# 4     PH1005       Kamal Uddin      In Progress     2024-03-05  Mr. Karim
# 5     PH1006       Laila Begum        Completed     2024-03-08  Ms. Salma
# 6     PH1007    Mahmudul Hasan      In Progress     2024-04-01  Mr. Karim
# 7     PH1008       Nadia Islam        Completed     2024-04-22  Ms. Salma
# 8     PH1009        Omar Faruq        Completed     2024-05-16  Mr. David
# 9     PH1010      Priya Sharma        Completed     2024-05-20  Ms. Salma
# 10    PH1011      Rahim Sheikh      In Progress     2024-06-11  Mr. Karim
# 11    PH1012   Sadia Chowdhury        Completed     2024-06-14  Ms. Salma
# 12    PH1013      Tanvir Ahmed        Completed     2024-07-02  Mr. David
# 13    PH1014        Urmi Akter      Not Started     2024-07-09  Ms. Salma
# 14    PH1015      Wahiduzzaman        Completed     2024-08-18  Mr. Karim
# 15    PH1016      Ziaur Rahman      In Progress     2024-08-21  Ms. Salma
# 16    PH1017       Afsana Mimi        Completed     2025-09-01  Mr. Karim
# 17    PH1018       Babul Ahmed        Completed     2025-09-05  Ms. Salma
# 18    PH1019      Faria Rahman      Not Started     2025-09-15  Mr. David
# 19    PH1020        Nasir Khan        Completed     2025-10-02  Ms. Salma
#
#       Location
# 0        Dhaka
# 1   Chattogram
# 2        Dhaka
# 3       Sylhet
# 4   Chattogram
# 5     Rajshahi
# 6        Dhaka
# 7   Chattogram
# 8        Dhaka
# 9       Sylhet
# 10      Khulna
# 11  Chattogram
# 12       Dhaka
# 13    Rajshahi
# 14       Dhaka
# 15  Chattogram
# 16       Dhaka
# 17      Sylhet
# 18  Chattogram
# 19       Dhaka

# %% [markdown]
# ### 2. Fill NaN Values

# %% [markdown]
# #### fill with constant value

# %% [markdown]
# - fill the NaN value with constant or specific values
#
# - df.fillna(value)
#
# - value => int, float, str

# %%
fill_with_zero = df.fillna(0)

fill_with_zero.head(8)
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   0.0              0.0
# 5    PH1006       Laila Begum                  75.0             75.0
# 6    PH1007    Mahmudul Hasan                  80.0             80.0
# 7    PH1008       Nadia Islam                  81.0             81.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           0.0      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
# 5          78.0        Completed     2024-03-08  Ms. Salma    Rajshahi
# 6           0.0      In Progress     2024-04-01  Mr. Karim       Dhaka
# 7          85.0        Completed     2024-04-22  Ms. Salma  Chattogram

# %% [markdown]
# - Fill the NaN value with specific column
#
# - syntax: df['col_name'].fillna(value)

# %%
fill_name = df['FullName'].fillna("Unknow")

fill_name.head(4)

# if FullName has at least one NaN value then it's replace with Unknow values
# Out:
# 0         Alif Rahman
# 1       Fatima Akhter
# 2       Imran Hossain
# 3    Jannatul Ferdous
# Name: FullName, dtype: object

# %% [markdown]
# #### fill with Statistical Measures

# %% [markdown]
# - Syntax:
#     - df['col_name'].fillna(df['col_name'].mean())
#
#     - col_name => Numerical must

# %%
df.head(2)
# Out:
#   StudentID       FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001    Alif Rahman                  85.0             85.0
# 1    PH1002  Fatima Akhter                  92.0             92.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram

# %%
# fill Python Marks column with it's mean values

df['Python Marks'].fillna(df['Python Marks'].mean(),inplace = True)

# if Python Marks column contain NaN value then it's fill with the mena values of it's column(Python Marks)

# %%
df.head(4)
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0     88.000000        Completed     2024-01-15  Mr. Karim       Dhaka
# 1     85.666667      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2     85.000000        Completed     2024-02-10  Mr. Karim       Dhaka
# 3     82.000000        Completed     2024-02-12  Ms. Salma      Sylhet

# %%
# fill Data Structure Marks with it's Median values

df['Data Structure Marks'].fillna(df['Data Structure Marks'].median())
# Out:
# 0     85.0
# 1     92.0
# 2     88.0
# 3     78.0
# 4     85.5
# 5     75.0
# 6     80.0
# 7     81.0
# 8     72.0
# 9     89.0
# 10    85.5
# 11    85.0
# 12    75.0
# 13    85.5
# 14    86.0
# 15    94.0
# 16    90.0
# 17    88.0
# 18    85.5
# 19    86.0
# Name: Data Structure Marks, dtype: float64

# %%
df.head(2)
# Out:
#   StudentID       FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001    Alif Rahman                  85.0             85.0
# 1    PH1002  Fatima Akhter                  92.0             92.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0     88.000000        Completed     2024-01-15  Mr. Karim       Dhaka
# 1     85.666667      In Progress     2024-01-20  Ms. Salma  Chattogram

# %%
# fill Algorithm Marks with it's column Mode values

df['Algorithm Marks'].fillna(df['Algorithm Marks'].mode(), inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12128\1062878302.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Algorithm Marks'].fillna(df['Algorithm Marks'].mode(), inplace = True)

# %%
df.head(3)
# Out:
#   StudentID       FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001    Alif Rahman                  85.0             85.0
# 1    PH1002  Fatima Akhter                  92.0             92.0
# 2    PH1003  Imran Hossain                  88.0             88.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0     88.000000        Completed     2024-01-15  Mr. Karim       Dhaka
# 1     85.666667      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2     85.000000        Completed     2024-02-10  Mr. Karim       Dhaka

# %% [markdown]
# ### Practice Example

# %%
import numpy as np

# %%
data = [
    {"emp_id": 101, "name": "John", "department": "IT", "salary": 85000, "age": 29},
    {"emp_id": 102, "name": "Anna", "department": None, "salary": 62000, "age": 31},
    {"emp_id": 103, "name": "David", "department": "Finance", "salary": np.nan, "age": 34},
    {"emp_id": 104, "name": "Lisa", "department": "IT", "salary": 85000, "age": np.nan},
    {"emp_id": 105, "name": "Tom", "department": "Marketing", "salary": 68000, "age": 27},
    {"emp_id": 106, "name": "Susan", "department": "Finance", "salary": None, "age": 34},
]

df = pd.DataFrame(data)
df
# Out:
#    emp_id   name department   salary   age
# 0     101   John         IT  85000.0  29.0
# 1     102   Anna       None  62000.0  31.0
# 2     103  David    Finance      NaN  34.0
# 3     104   Lisa         IT  85000.0   NaN
# 4     105    Tom  Marketing  68000.0  27.0
# 5     106  Susan    Finance      NaN  34.0

# %% [markdown]
# #### Task 1
#  - Drop all rows that contain any NaN values.

# %%
df.dropna(how = 'any')
# Out:
#    emp_id  name department   salary   age
# 0     101  John         IT  85000.0  29.0
# 4     105   Tom  Marketing  68000.0  27.0

# %% [markdown]
# #### Task 2
# - Drop rows where the department column has NaN

# %%
df.dropna(subset= ['department'])
# Out:
#    emp_id   name department   salary   age
# 0     101   John         IT  85000.0  29.0
# 2     103  David    Finance  75000.0  34.0
# 3     104   Lisa         IT  85000.0  31.0
# 4     105    Tom  Marketing  68000.0  27.0
# 5     106  Susan    Finance  75000.0  34.0

# %%
df['department'].dropna()
# Out:
# 0           IT
# 2      Finance
# 3           IT
# 4    Marketing
# 5      Finance
# Name: department, dtype: object

# %%
df
# Out:
#    emp_id   name department   salary   age
# 0     101   John         IT  85000.0  29.0
# 1     102   Anna       None  62000.0  31.0
# 2     103  David    Finance      NaN  34.0
# 3     104   Lisa         IT  85000.0   NaN
# 4     105    Tom  Marketing  68000.0  27.0
# 5     106  Susan    Finance      NaN  34.0

# %% [markdown]
# Task 3
#
# Fill all missing values with "Unknown".

# %%
df.fillna("Unknown")
# Out:
#    emp_id   name department   salary      age
# 0     101   John         IT  85000.0     29.0
# 1     102   Anna    Unknown  62000.0     31.0
# 2     103  David    Finance  Unknown     34.0
# 3     104   Lisa         IT  85000.0  Unknown
# 4     105    Tom  Marketing  68000.0     27.0
# 5     106  Susan    Finance  Unknown     34.0

# %%
# fill values with Unknown in only department column

df['department'].fillna("Unknown")
# Out:
# 0           IT
# 1      Unknown
# 2      Finance
# 3           IT
# 4    Marketing
# 5      Finance
# Name: department, dtype: object

# %%
df
# Out:
#    emp_id   name department   salary   age
# 0     101   John         IT  85000.0  29.0
# 1     102   Anna       None  62000.0  31.0
# 2     103  David    Finance      NaN  34.0
# 3     104   Lisa         IT  85000.0   NaN
# 4     105    Tom  Marketing  68000.0  27.0
# 5     106  Susan    Finance      NaN  34.0

# %% [markdown]
# #### Task 4
# - Fill missing values in the salary column with the average salary.

# %%
df['salary'].fillna(df['salary'].mean(), inplace = True)

df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12128\3506162352.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['salary'].fillna(df['salary'].mean(), inplace = True)
#    emp_id   name department   salary   age
# 0     101   John         IT  85000.0  29.0
# 1     102   Anna       None  62000.0  31.0
# 2     103  David    Finance  75000.0  34.0
# 3     104   Lisa         IT  85000.0   NaN
# 4     105    Tom  Marketing  68000.0  27.0
# 5     106  Susan    Finance  75000.0  34.0

# %% [markdown]
# #### Task 5
# - Fill missing values in the age column with the median age.

# %%
df['age'].fillna(df['age'].median(),inplace = True)

df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12128\3668286440.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(),inplace = True)
#    emp_id   name department   salary   age
# 0     101   John         IT  85000.0  29.0
# 1     102   Anna       None  62000.0  31.0
# 2     103  David    Finance  75000.0  34.0
# 3     104   Lisa         IT  85000.0  31.0
# 4     105    Tom  Marketing  68000.0  27.0
# 5     106  Susan    Finance  75000.0  34.0

# %% [markdown]
# #### Task 6
# - Check how many missing values exist before and after cleaning:

# %%
len(df)
# Out:
# 6

# %%
len(new_df)

# same value because we directly change in df.
# Out:
# 6
