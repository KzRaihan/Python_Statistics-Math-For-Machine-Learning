# %% [markdown]
# ## Topic: Data Analysis with Pandas part -2

# %% [markdown]
# ### OUTCOMES
#
# - 1. Filtering based on String.
#
# - 2. Adding new column and saving to local storage.
#
# - 3. Checking Duplicates and Null Values in DF
#
# - 4. Handling Duplicate Values
#
# - 5. Handling Null Values
#
# - 6. Statistical Functions in Pandas.
#
# - 7. apply() Function in DF
#
# - 8. DateTime and Timedelta
#
# - 9. GroupBy in DF
#
# - 10. Problem Solving in LeeCode
