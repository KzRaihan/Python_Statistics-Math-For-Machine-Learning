# %% [markdown]
# ## Topic: Data Visualization With Seaborn and Plotly

# %% [markdown]
# # OUTCOMES
#
# - 1. lineplot using seaborn
#
# - 2. scatterplot using seaborn
#
# - 3. Facet plot using seaborn.
#
# - 4. Histogram using seaborn.
#
# - 5. KDE plot using seaborn.
#
# - 6. count & Barplot using seaborn.
#
# - 7. pairplot and jointplot using sns.
#
# - 8. scatter plot With Plotly.
#
# - 9. Histogram using plotyly
