# %% [markdown]
# ## Topic: Data Visualization with Matplotlib

# %% [markdown]
# ### OUTCOMES
#
# - 1. Intro Matplotlib and  Basic of 2-d line plot.
#
# - 2. Usage of Scatter Plot
#
# - 3. Histogram
#
# - 4. Bar Chart
#
# - 5. Pie Chart
